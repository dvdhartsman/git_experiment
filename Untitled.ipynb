# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from scipy import stats
import statsmodels

# %%
df = pd.read_csv("/Users/samalainabayeva/Desktop/final_data.csv")

# %%
df.head()
# Out:
#     movie_id                     genres  avg_ratings  num_votes region  \
# 0  tt0369610    Action,Adventure,Sci-Fi          7.0     539338     BG
# 1  tt0401729    Action,Adventure,Sci-Fi          6.6     241792     UA
# 2  tt1014759   Adventure,Family,Fantasy          6.5     358813     IE
# 3  tt1194173  Action,Adventure,Thriller          6.7     268678     RS
# 4  tt1219289    Mystery,Sci-Fi,Thriller          7.4     492490     AR
#
#    category      artist_name  screen_time          movie_title  death_year  \
# 0  producer  Patrick Crowley        124.0       Jurassic World         NaN
# 1     actor     Willem Dafoe        132.0          John Carter         NaN
# 2     actor      Johnny Depp        108.0  Alice in Wonderland         NaN
# 3     actor      Scott Glenn        135.0    The Bourne Legacy         NaN
# 4     actor   Robert De Niro        105.0            Limitless         NaN
#
#    ...  release_date                movie production_budget domestic_gross  \
# ...

# %%
df.dtypes
# Out:
# movie_id              object
# genres                object
# avg_ratings          float64
# num_votes              int64
# region                object
# category              object
# artist_name           object
# screen_time          float64
# movie_title           object
# death_year           float64
# weighted_avg         float64
# id                     int64
# release_date          object
# movie                 object
# production_budget    float64
# domestic_gross       float64
# worldwide_gross      float64
# release_year           int64
# release_month          int64
# foreign_gross        float64
# total_profit         float64
# roi                  float64
# dtype: object

# %%
# Out:
# 12

# %%
months = df.groupby("release_month")
genres = df.groupby("genres")

# %%
df.groupby(['genres', 'release_month'])['total_profit'].sum()
# Out:
# genres    release_month
# Action    1                 128.733800
#           2                  10.384136
#           3                  35.538560
#           6                   5.900000
#           10                 -5.446814
#                               ...
# Thriller  9                  -8.013794
#           10               1147.865879
#           11                 63.247738
#           12                174.142619
# War       8                  -9.800895
# Name: total_profit, Length: 890, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.lineplot(x="release_month", y="total_profit", data=df[df["genres"].str.contains("Horror")])
sns.lineplot(x="release_month", y="total_profit", data=df[df["genres"].str.contains("Action")])
sns.lineplot(x="release_month", y="total_profit", data=df[df["genres"].str.contains("Drama")])
sns.lineplot(x="release_month", y="total_profit", data=df[df["genres"].str.contains("Comedy")])
sns.lineplot(x="release_month", y="total_profit", data=df[df["genres"].str.contains("Animation")])
plt.legend(['Horror', "Action", "Drama", " Comedy", "Animation"]);
